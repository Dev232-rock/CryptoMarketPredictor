# %%
# %tensorflow_version 2.x
import json
import requests
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
# %matplotlib inline

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=BTC&tsym=CAD&limit=500')
#hist = pd.DataFrame(json.loads(res.content)['Data'])
data = json.loads(res.content)['Data']
for element in data:
  element.pop('conversionType', None)
  element.pop('conversionSymbol', None)

hist = pd.DataFrame(data)
hist = hist.set_index('time')
hist.index = pd.to_datetime(hist.index, unit='s')
target_col = 'close'

# %%
hist.head(5)
# Out:
#                 high       low      open  volumefrom    volumeto     close
# time
# 2020-08-15  15970.11  15676.67  15680.19       86.65  1371693.75  15845.60
# 2020-08-16  15993.48  15636.72  15845.60       65.36  1034606.65  15893.32
# 2020-08-17  16526.05  15728.82  15893.32      115.21  1866990.53  16354.99
# 2020-08-18  16437.46  15813.92  16354.99      131.12  2113154.41  15876.64
# 2020-08-19  15951.16  15467.20  15876.64      111.49  1748036.52  15650.28

# %%
def train_test_split(df, test_size=0.2):
    split_row = len(df) - int(test_size * len(df))
    train_data = df.iloc[:split_row]
    test_data = df.iloc[split_row:]
    return train_data, test_data

# %%
train, test = train_test_split(hist, test_size=0.2)

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16);

# %%
line_plot(train[target_col], test[target_col], 'training', 'test', title='')

# %%
def normalise_zero_base(df):
    return df / df.iloc[0] - 1

def normalise_min_max(df):
    return (df - df.min()) / (data.max() - df.min())

# %%
def extract_window_data(df, window_len=5, zero_base=True):
    window_data = []
    for idx in range(len(df) - window_len):
        tmp = df[idx: (idx + window_len)].copy()
        if zero_base:
            tmp = normalise_zero_base(tmp)
        window_data.append(tmp.values)
    return np.array(window_data)

# %%
def prepare_data(df, target_col, window_len=10, zero_base=True, test_size=0.2):
    train_data, test_data = train_test_split(df, test_size=test_size)
    X_train = extract_window_data(train_data, window_len, zero_base)
    X_test = extract_window_data(test_data, window_len, zero_base)
    y_train = train_data[target_col][window_len:].values
    y_test = test_data[target_col][window_len:].values
    if zero_base:
        y_train = y_train / train_data[target_col][:-window_len].values - 1
        y_test = y_test / test_data[target_col][:-window_len].values - 1

    return train_data, test_data, X_train, X_test, y_train, y_test

# %%
def build_lstm_model(input_data, output_size, neurons=100, activ_func='linear',
                     dropout=0.2, loss='mse', optimizer='adam'):
    model = Sequential()
    model.add(LSTM(neurons, input_shape=(input_data.shape[1], input_data.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activ_func))

    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
np.random.seed(42)
window_len = 5
test_size = 0.2
zero_base = True
lstm_neurons = 100
epochs = 20
batch_size = 32
loss = 'mse'
dropout = 0.2
optimizer = 'adam'

# %%
train, test, X_train, X_test, y_train, y_test = prepare_data(
    hist, target_col, window_len=window_len, zero_base=zero_base, test_size=test_size)
model = build_lstm_model(
    X_train, output_size=1, neurons=lstm_neurons, dropout=dropout, loss=loss,
    optimizer=optimizer)
history = model.fit(
    X_train, y_train, epochs=200, batch_size=batch_size, verbose=1, shuffle=True)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 8ms/step - loss: 0.0091
# Epoch 2/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 3/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0059
# Epoch 4/200
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0045
# Epoch 5/200
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0052
# Epoch 6/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0048
# Epoch 7/200
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 8/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0048
# Epoch 9/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 10/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 11/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0035
# Epoch 12/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 13/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0031
# Epoch 14/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 15/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 16/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0042
# Epoch 17/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 18/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 19/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 20/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 21/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 22/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 23/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0025
# Epoch 24/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 25/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 26/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 27/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 28/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 29/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 30/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 31/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 32/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0022
# Epoch 33/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028
# Epoch 34/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 35/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 36/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 37/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 38/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 39/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 40/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 41/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 42/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 43/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 44/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 45/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 46/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0021
# Epoch 47/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 48/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 49/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 50/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 51/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 52/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 53/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 54/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 55/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 56/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 57/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 58/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 59/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 60/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 61/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 62/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 63/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 64/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 65/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 66/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 67/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 68/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0022
# Epoch 69/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 70/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 71/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 72/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 73/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 74/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 75/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 76/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 77/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 78/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 79/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 80/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 81/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 82/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 83/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 84/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 85/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 86/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 87/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 88/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 89/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 90/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 91/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 92/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 93/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 94/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 95/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 96/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 97/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 98/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 99/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 100/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 101/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 102/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 103/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 104/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 105/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 106/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 107/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 108/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 109/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 110/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 111/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 112/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 113/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 114/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 115/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 116/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 117/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 118/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 119/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 120/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 121/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 122/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 123/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 124/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 125/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 126/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 127/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 128/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 129/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 130/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 131/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 132/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 133/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 134/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 135/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 136/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 137/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 138/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 139/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 140/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 141/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 142/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 143/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 144/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 145/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 146/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 147/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 148/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 149/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 150/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 151/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 152/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 153/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 154/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 155/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 156/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 157/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 158/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 159/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 160/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 161/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 162/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 163/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 164/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 165/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 166/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 167/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 168/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 169/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 170/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 171/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 172/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 173/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 174/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 175/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 176/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 177/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 178/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 179/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 180/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 181/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 182/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 183/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 184/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 185/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 186/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 187/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 188/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 189/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 190/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 191/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 192/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 193/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 194/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 195/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 196/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 197/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 198/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 199/200
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 200/200
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016

# %%
targets = test[target_col][window_len:]
preds = model.predict(X_test).squeeze()
mean_absolute_error(preds, y_test)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f55f64bb4d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 0.025627144650143232

# %%
preds = test[target_col].values[:-window_len] * (preds + 1)
preds = pd.Series(index=targets.index, data=preds)
line_plot(targets, preds, 'actual', 'prediction', lw=3)
